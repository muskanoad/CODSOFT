# %% [markdown]
# # SALES PREDICTION USING PYTHON

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import rcParams
rcParams ['figure.figsize'] = 15,5
sns.set_style('darkgrid')

# %%
data= pd.read_csv('/Users/muskanoad/Downloads/advertising.csv')
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %% [markdown]
# # Data Cleaning

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# All the data is cleaned since there are no missing values

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.pairplot(data=data)
plt.show()

# %%
plt.boxplot(data['TV'])
plt.show()

# %%
plt.boxplot(data['Radio'])
plt.show()

# %%
plt.boxplot(data['Newspaper'])
plt.show()

# %%
plt.boxplot(data['Radio'])
plt.show()

# %%
sns.boxplot(data=data)
plt.title('Boxplot')
plt.show()

# %%
X = data[['TV','Radio','Newspaper']]
y = data['Sales']

# %% [markdown]
# # Data Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Model Training (Linear Regression)

# %%
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %% [markdown]
# # Model Evaluation

# %%
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 2.541624036229147
# R-squared: 0.9091484341849799

# %% [markdown]
# There is a strong indication that the Linear Regression model with these features is effective for predicting sales in the context of your advertising dataset.

# %% [markdown]
# # Model Training (Random Forest Regression)

# %%
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)

# %%
model_rf.fit(X_train, y_train)

y_pred_rf = model_rf.predict(X_test)

# %%
mse_rf = mean_squared_error(y_test, y_pred_rf)
r2_rf = r2_score(y_test, y_pred_rf)

# %% [markdown]
# # Model Evaluation

# %%
print("Random Forest Regression Model:")
print(f"Mean Squared Error: {mse_rf}")
print(f"R-squared: {r2_rf}")
# Out:
# Random Forest Regression Model:
# Mean Squared Error: 1.6719851000000026
# R-squared: 0.9402340935602138

# %%
correlation_matrix = data.corr()

plt.figure(figsize=(10, 8))  
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Heatmap")
plt.show()
